# %%
from CactusTool.funcs import *
from CactusTool.Carpet.grid import UniformGrid

# %%
file = '/Users/liuyu/simulations/BH/ml_admconstraints-ml_mom.xy.h5'
a = header_h5(file)
a
# Out:
# {'ML_ADMCONSTRAINTS::M1 it=0 tl=0 rl=0 c=0': {'thorn': 'ML_ADMCONSTRAINTS',
#   'varname': 'M1',
#   'iteration': 0,
#   'timelevel': 0,
#   'rl': 0,
#   'c': 0},
#  'ML_ADMCONSTRAINTS::M1 it=0 tl=0 rl=0 c=10': {'thorn': 'ML_ADMCONSTRAINTS',
#   'varname': 'M1',
#   'iteration': 0,
#   'timelevel': 0,
#   'rl': 0,
#   'c': 10},
#  'ML_ADMCONSTRAINTS::M1 it=0 tl=0 rl=0 c=12': {'thorn': 'ML_ADMCONSTRAINTS',
#   'varname': 'M1',
#   'iteration': 0,
#   'timelevel': 0,
#   'rl': 0,
#   'c': 12},
#  'ML_ADMCONSTRAINTS::M1 it=0 tl=0 rl=0 c=14': {'thorn': 'ML_ADMCONSTRAINTS',
#   'varname': 'M1',
#   'iteration': 0,
#   'timelevel': 0,
#   'rl': 0,
#   'c': 14},
#  'ML_ADMCONSTRAINTS::M1 it=0 tl=0 rl=0 c=15': {'thorn': 'ML_ADMCONSTRAINTS',
#   'varname': 'M1',
#   'iteration': 0,
#   'timelevel': 0,
#   'rl': 0,
#   'c': 15},
#  'ML_ADMCONSTRAINTS::M1 it=0 tl=0 rl=0 c=17': {'thorn': 'ML_ADMCONSTRAINTS',
#   'varname': 'M1',
#   'iteration': 0,
#   'timelevel': 0,
#   'rl': 0,
#   'c': 17},
# ...

# %%
a = dataset_h5(file, 'ML_ADMCONSTRAINTS::M1 it=0 tl=0 rl=0 c=2')
UniformGrid(a)
# Out:
# {'active': b'bboxset<CCTK_INT4,2>(set<bbox>:{([3840,768]:[9984,3584]:[256,256]/[15,3]:[39,14]/[25,12]/300)},stride:[256,256],offset:[0,0])',
#  'carpet_mglevel': 0,
#  'cctk_bbox': array([0, 0, 1, 0], dtype=int32),
#  'cctk_nghostzones': array([3, 3], dtype=int32),
#  'delta': array([10., 10.]),
#  'group_timelevel': 0,
#  'ioffset': array([0, 0], dtype=int32),
#  'ioffsetdenom': array([256, 256], dtype=int32),
#  'iorigin': array([15,  0], dtype=int32),
#  'level': 0,
#  'name': b'ML_ADMCONSTRAINTS::M1',
#  'origin': array([ -80., -230.]),
#  'time': 0.0,
#  'timestep': 0,
#  'data': array([[ 1.60545864e-15, -4.52805954e-15, -1.15096705e-14,
#          -1.71328632e-14, -1.93023661e-14, -1.71638950e-14,
#          -1.17877364e-14, -5.80899223e-15, -2.05278939e-15,
#          -1.94275728e-15, -4.74913303e-15, -8.17499286e-15,
#          -9.82488660e-15, -8.53732156e-15, -4.79939927e-15,
#          -1.94562849e-16,  3.57266900e-15,  5.44643796e-15,
# ...

# %%
with read(file) as f:
    a = f[u'Parameters and Global Attributes']
    print(np.array(a))
# Out:
# ['All Parameters' 'Datasets' 'Grid Structure v5']

# %%
with read(file) as f:
    a = f[u'Parameters and Global Attributes']
    print(np.array(a['Grid Structure v5']))
# Out:
# b'grid_superstructure:[[[region_t(extent=([0,0,0]:[11520,11520,6400]:[256,256,256]/[0,0,0]:[45,45,25]/[46,46,26]/55016),outer_boundaries=[[1,1,1],[1,1,1]],map=0,processor=-1)],[region_t(extent=([1536,1664,384]:[10240,10112,4992]:[128,128,128]/[12,13,3]:[80,79,39]/[69,67,37]/171051),outer_boundaries=[[0,0,1],[0,0,0]],map=0,processor=-1)],[region_t(extent=([3648,3776,576]:[8128,8000,2880]:[64,64,64]/[57,59,9]:[127,125,45]/[71,67,37]/176009),outer_boundaries=[[0,0,1],[0,0,0]],map=0,processor=-1)],[region_t(extent=([4704,4832,672]:[7072,6944,1824]:[32,32,32]/[147,151,21]:[221,217,57]/[75,67,37]/185925),outer_boundaries=[[0,0,1],[0,0,0]],map=0,processor=-1)],[region_t(extent=([5232,5376,720]:[6528,6400,1280]:[16,16,16]/[327,336,45]:[408,400,80]/[82,65,36]/191880),outer_boundaries=[[0,0,1],[0,0,0]],map=0,processor=-1)],[region_t(extent=([5496,5640,744]:[6256,6136,1016]:[8,8,8]/[687,705,93]:[782,767,127]/[96,63,35]/211680),outer_boundaries=[[0,0,1],[0,0,0]],map=0,processor=-1)],[region_t(ex
# ...

# %%
import CactusTool
import matplotlib.pyplot as plt
import numpy as np

path = '/Users/liuyu/simulations/BH/'
sim = CactusTool.load(path)

# %%
import pandas as pd
table = sim.ASCII.x['H'].dataset
# table = table[table.time==0]
# table = table[table.rl==9]
# table = table[['it', 'time']].drop_duplicates()
a = pd.Series(table['time'].values, index=table['it']).drop_duplicates()
a[256.0 ]
# Out:
# 1.0

# %%
from scipy import interpolate

f = interpolate.interp1d(table.x, table.H, kind='cubic')
f(0)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-8-0e0f4a0f92c9> in <module>
#       1 from scipy import interpolate
#       2
# ----> 3 f = interpolate.interp1d(table.x, table.H, kind='cubic')
#       4 f(0)
#
# /usr/local/lib/python3.7/site-packages/scipy/interpolate/interpolate.py in __init__(***failed resolving arguments***)
#     531
#     532             self._spline = make_interp_spline(xx, yy, k=order,
# --> 533                                               check_finite=False)
#     534             if rewrite_nan:
#     535                 self._call = self.__class__._call_nan_spline
#
# /usr/local/lib/python3.7/site-packages/scipy/interpolate/_bsplines.py in make_interp_spline(x, y, k, t, bc_type, axis, check_finite)
#     797
#     798     if x.ndim != 1 or np.any(x[1:] <= x[:-1]):
# ...

# %%
xnew = np.arange(-200, 200, 0.01)
ynew = f(xnew)
plt.plot(table.x, table.H, '.')
plt.plot(xnew, ynew, '-')
plt.show()
