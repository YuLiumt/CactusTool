# %%
import CactusTool

name = 'GW150914_test14'
sim = CactusTool.load(name, '/Volumes/simulations/HUST_error')

# name = 'BBH003Lev1'
# sim = CactusTool.load(name, '/Volumes/simulations/BBH_Catalog')

trajectory = sim.ThornOutput('puncturetracker')
bbh = sim.ThornOutput('twopunctures')

# %%
trajectory.preview()
# Out:
# array([4.92549095e-05, 4.92563941e-05, 4.92516337e-05, 4.92552263e-05,
#        4.92602112e-05, 4.92636362e-05, 4.92678015e-05, 4.92734464e-05,
#        4.92800872e-05, 4.92884863e-05, 4.92988613e-05, 4.93107442e-05,
#        4.93237926e-05, 4.93380085e-05, 4.93535534e-05, 4.93705179e-05,
#        4.93888099e-05, 4.94083991e-05, 4.94291743e-05, 4.94509336e-05,
#        4.94736515e-05, 4.94974600e-05, 4.95224897e-05, 4.95487787e-05,
#        4.95762961e-05, 4.96050374e-05, 4.96349396e-05, 4.96659506e-05,
#        4.96980071e-05, 4.97310719e-05, 4.97650831e-05, 4.97998676e-05,
#        4.98349386e-05, 4.98695345e-05, 4.99034330e-05, 4.99366355e-05,
#        4.99695425e-05, 5.00026750e-05, 5.00358606e-05, 5.00684883e-05,
#        5.01001887e-05, 5.01307911e-05, 5.01601853e-05, 5.01883457e-05,
#        5.02150617e-05, 5.02402445e-05, 5.02638202e-05, 5.02857079e-05,
#        5.03057953e-05, 5.03240249e-05, 5.03404438e-05, 5.03550142e-05,
#        5.03677840e-05, 5.03787955e-05, 5.03880787e-05, 5.03956779e-05,
#        5.04015985e-05, 5.04059678e-05, 5.04088275e-05, 5.04103096e-05,
#        5.04105056e-05, 5.04095276e-05, 5.04074289e-05, 5.04043212e-05,
#        5.04003171e-05, 5.03956117e-05, 5.03903650e-05, 5.03847039e-05,
#        5.03787116e-05, 5.03724939e-05, 5.03661586e-05, 5.03598248e-05,
#        5.03535972e-05, 5.03475573e-05, 5.03418000e-05, 5.03363032e-05,
#        5.03311052e-05, 5.03262179e-05, 5.03216558e-05, 5.03174848e-05,
#        5.03137137e-05, 5.03102868e-05, 5.03072430e-05, 5.03047194e-05,
#        5.03024506e-05, 5.03004120e-05, 5.02988285e-05, 5.02975850e-05,
#        5.02965692e-05, 5.02959024e-05, 5.02956160e-05, 5.02953335e-05,
#        5.02950787e-05, 5.02952216e-05, 5.02955492e-05, 5.02958797e-05,
#        5.02962992e-05, 5.02968530e-05, 5.02974597e-05, 5.02982792e-05,
#        5.02994530e-05, 5.03007997e-05, 5.03021558e-05, 5.03036843e-05,
#        5.03053985e-05, 5.03071181e-05, 5.03086903e-05, 5.03100503e-05,
#        5.03112308e-05, 5.03123168e-05, 5.03133970e-05, 5.03145088e-05,
#        5.03155825e-05, 5.03165640e-05, 5.03174086e-05, 5.03180985e-05,
#        5.03186921e-05, 5.03192459e-05, 5.03197288e-05, 5.03201212e-05,
#        5.03204807e-05, 5.03208236e-05, 5.03210339e-05, 5.03211160e-05,
#        5.03211686e-05, 5.03211927e-05, 5.03211643e-05, 5.03211029e-05,
#        5.03210906e-05, 5.03210755e-05, 5.03209867e-05, 5.03208776e-05,
#        5.03574069e-05, 5.03566571e-05, 5.03559000e-05, 5.03551518e-05,
#        5.03544242e-05, 5.03537403e-05, 5.03530773e-05, 5.03524144e-05,
#        5.03517466e-05, 5.03510711e-05, 5.03503857e-05, 5.03496960e-05,
#        5.03490050e-05, 5.03483018e-05, 5.03475836e-05, 5.03468596e-05,
#        5.03461398e-05, 5.03454292e-05, 5.03447176e-05, 5.03439958e-05,
#        5.03432755e-05, 5.03425634e-05, 5.03418606e-05, 5.03411704e-05,
#        5.03404916e-05, 5.03398161e-05])

# %%
trajectory.e_Omega(bbh.ADMMass, bbh.eta, bbh.chi1, bbh.chi2)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-15-4d6ba5c6d9fb> in <module>
# ----> 1 trajectory.e_Omega(bbh.ADMMass, bbh.eta, bbh.chi1, bbh.chi2)
#
# ~/Desktop/CactusTool/CactusTool/Analysis/Trajectory.py in e_Omega(self, ADM_Mass, eta, chi_1, chi_2, MinTime, MaxTime)
#      47
#      48         Omega_0 = m_omega_r35SPN(D0,q,chi_1,chi_2,1.) if m_omega_r35SPN(D0,q,chi_1,chi_2,1.) > 10e-6 else 0
# ---> 49         omega_data = self.omega.norm.clip(MinTime, max(MaxTime, 2/3 * self.tmerger()))
#      50
#      51         MAXTime = tCoal0PN(eta=eta, total_mass=ADM_Mass, separation=D0)
#
# ~/Desktop/CactusTool/CactusTool/Analysis/DiscreteFunction.py in clip(self, tmin, tmax)
#      62         t = self.t
#      63         index = np.where((t >= tmin) & (t <= tmax))
# ---> 64         return self.__class__(t[index], self.y[index])
#      65
#      66     def smooth(self, window_len=11, window='hanning'):
#
# ~/Desktop/CactusTool/CactusTool/Analysis/DiscreteFunction.py in __init__(self, t, y)
#      18         """
#      19         if len(y) < 1:
# ---> 20             raise ValueError('initial_array must contain at least one sample.')
#      21         assert len(t) == len(y), "Times and Values length mismatch"
#      22
#
# ValueError: initial_array must contain at least one sample.

# %%
trajectory.eccentricity()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-12-2fbd4554628c> in <module>
# ----> 1 trajectory.eccentricity()
#
# ~/Desktop/CactusTool/CactusTool/Analysis/Trajectory.py in eccentricity(self, p0)
#      97
#      98         # The fit is performed in the time interval between $t_{\mathrm{ret}}=50 \mathrm{M}$ and $t_{\mathrm{ret}}=\frac{2}{3} t_{\mathrm{merger}}$ to avoid the initial spurious radiation and the plunge phase but having at least one eccentricity cycle included.
# ---> 99         ddot = self.r.norm.gradient().clip(50, 2/3 * self.tmerger())
#     100         t = ddot.t
#     101         y = ddot.y
#
# ~/Desktop/CactusTool/CactusTool/Analysis/DiscreteFunction.py in clip(self, tmin, tmax)
#      62         t = self.t
#      63         index = np.where((t >= tmin) & (t <= tmax))
# ---> 64         return self.__class__(t[index], self.y[index])
#      65
#      66     def smooth(self, window_len=11, window='hanning'):
#
# ~/Desktop/CactusTool/CactusTool/Analysis/DiscreteFunction.py in __init__(self, t, y)
#      18         """
#      19         if len(y) < 1:
# ---> 20             raise ValueError('initial_array must contain at least one sample.')
#      21         assert len(t) == len(y), "Times and Values length mismatch"
#      22
#
# ValueError: initial_array must contain at least one sample.
