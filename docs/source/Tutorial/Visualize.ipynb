# %% [markdown]
# # Visualize

# %%
# %matplotlib inline
import ipywidgets as widgets
from ipywidgets import interactive_output, HBox, VBox
import CactusTool
import matplotlib.pyplot as plt
import numpy as np

path = '/Users/liuyu/simulations/BH/'
sim = CactusTool.load(path)

# %% [markdown]
# ## TimeSeries

# %%
from CactusTool import TimeSeries
from scipy.interpolate import interp1d
var = sim.Scalar.max['arena_mb'] # All scalar
table = var.dataset()
a = interp1d(table['time'], table['arena_mb'])
x = np.linspace(0, 60)

fig, ax = plt.subplots()
ax.plot(x, a(x))
plt.show()

# %% [markdown]
# ## LinePlot

# %%
from CactusTool import LinePlot

# var = sim.ASCII.x['H'] # All scalar
# var.data
# fig, ax = plt.subplots()
# line = LinePlot(ax, var.dataset)
# # ts.plot('H')
# plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-9-90eef8b76dca> in <module>
#       1 a = ([1, 2, 3], [2, 3, 4])
# ----> 2 a.shape
#
# AttributeError: 'tuple' object has no attribute 'shape'
