# %% [markdown]
# ## Neutron Star

# %%
import CactusTool

name = 'nsnstohmns'
sim = CactusTool.load(name, '/Volumes/simulations')
sim.Scalar('scalars').fname
# Out:
# {'admbase-curv',
#  'admbase-lapse',
#  'admbase-metric',
#  'admbase-shift',
#  'grhydro-dens',
#  'hydrobase-rho',
#  'hydrobase-vel',
#  'hydrobase-w_lorentz',
#  'ml_admconstraints-ml_ham',
#  'sphericalsurface-sf_radius',
#  'systemstatistics-process_memory_mb'}

# %%
p = sim.Scalar('scalars')['hydrobase-rho'].dsets('rho(maximum)')

# %%
from CactusTool import TimeSeries
import matplotlib.pyplot as plt

fig, ax = plt.subplots(figsize=(10,4))
TimeSeries(ax, p)
ax.set_title('H(maximum)')
plt.rcParams['xtick.direction'] = 'in'
plt.rcParams['ytick.direction'] = 'in'
plt.show()
